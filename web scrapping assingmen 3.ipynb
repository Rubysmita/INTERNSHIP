# %%
# !pip install selenium
# Out:
# Requirement already satisfied: selenium in e:\aani\lib\site-packages (4.1.0)
# Requirement already satisfied: trio-websocket~=0.9 in e:\aani\lib\site-packages (from selenium) (0.9.2)
# Requirement already satisfied: urllib3[secure]~=1.26 in e:\aani\lib\site-packages (from selenium) (1.26.4)
# Requirement already satisfied: trio~=0.17 in e:\aani\lib\site-packages (from selenium) (0.19.0)
# Requirement already satisfied: attrs>=19.2.0 in e:\aani\lib\site-packages (from trio~=0.17->selenium) (20.3.0)
# Requirement already satisfied: outcome in e:\aani\lib\site-packages (from trio~=0.17->selenium) (1.1.0)
# Requirement already satisfied: sniffio in e:\aani\lib\site-packages (from trio~=0.17->selenium) (1.2.0)
# Requirement already satisfied: idna in e:\aani\lib\site-packages (from trio~=0.17->selenium) (2.10)
# Requirement already satisfied: async-generator>=1.9 in e:\aani\lib\site-packages (from trio~=0.17->selenium) (1.10)
# Requirement already satisfied: sortedcontainers in e:\aani\lib\site-packages (from trio~=0.17->selenium) (2.3.0)
# Requirement already satisfied: cffi>=1.14 in e:\aani\lib\site-packages (from trio~=0.17->selenium) (1.14.5)
# Requirement already satisfied: pycparser in e:\aani\lib\site-packages (from cffi>=1.14->trio~=0.17->selenium) (2.20)
# Requirement already satisfied: wsproto>=0.14 in e:\aani\lib\site-packages (from trio-websocket~=0.9->selenium) (1.0.0)
# Requirement already satisfied: cryptography>=1.3.4 in e:\aani\lib\site-packages (from urllib3[secure]~=1.26->selenium) (3.4.7)
# Requirement already satisfied: pyOpenSSL>=0.14 in e:\aani\lib\site-packages (from urllib3[secure]~=1.26->selenium) (20.0.1)
# Requirement already satisfied: certifi in e:\aani\lib\site-packages (from urllib3[secure]~=1.26->selenium) (2020.12.5)
# Requirement already satisfied: six>=1.5.2 in e:\aani\lib\site-packages (from pyOpenSSL>=0.14->urllib3[secure]~=1.26->selenium) (1.15.0)
# Requirement already satisfied: h11<1,>=0.9.0 in e:\aani\lib\site-packages (from wsproto>=0.14->trio-websocket~=0.9->selenium) (0.12.0)

# %% [markdown]
# 4. Write a python program to search for a smartphone(e.g.: Oneplus Nord, pixel 4A, etc.) on
# www.flipkart.com and scrape following details for all the search results displayed on 1st page. Details to be
# scraped: “Brand Name”, “Smartphone name”, “Colour”, “RAM”, “Storage(ROM)”, “Primary Camera”,
# “Secondary Camera”, “Display Size”, “Battery Capacity”, “Price”, “Product URL”. Incase if any of the
# details is missing then replace it by “- “. Save your results in a dataframe and CSV.

# %%
#Importing required libraries
import selenium
import pandas as pd
from selenium import webdriver
import time
from selenium.common.exceptions import NoSuchElementException
from selenium.webdriver.common.keys import Keys

# %%
driver=webdriver.Chrome(r"C:/Users/user/Downloads/chromedriver_win32 (1)/chromedriver.exe")
# Out:
# <ipython-input-9-e86b318ec392>:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver=webdriver.Chrome(r"C:/Users/user/Downloads/chromedriver_win32 (1)/chromedriver.exe")

# %%
#driver.close()

# %%
driver.get('https://www.images.google.com/')

# %%
def get_images(keywords):
    driver.get('https://www.images.google.com/')
    
    #Searching the keywords in the search bar and clicking the search button
    search_bar=driver.find_element_by_xpath("//input[@class='gLFyf gsfi']")
    search_bar.send_keys(keywords)
    button=driver.find_element_by_xpath("//button[@class='Tg7LZd']")
    button.click()
    driver.implicitly_wait(1)  #Making the driver wait for 1 second
    
    #Taking 5 pages for each keyword and scraping the image data
    for page in range(0,5):
        driver.find_element_by_xpath("//a[@class='wXeWr islib nfEiy mM5pbd']").send_keys(Keys.PAGE_DOWN)
        time.sleep(2)   #Delaying the page wait time for 2 seconds
        
        #Iterating data for first 100 results of the keywords
        picture=[image for image in driver.find_elements_by_xpath("//a[@class='wXeWr islib nfEiy mM5pbd']")[:100]]
        image_url=[]   #Empty list
        print(len(picture))  
        
        #Iterating the tags for getting url link text of 100 results
        if(len(picture)==100):  #Checking if the length is equal to 100
            for i in picture:
                try:
                    i.click()
                    image_url.append(i.get_attribute('href'))  #Extracting the link texts
                except NoSuchElementException as e:
                    image_url.append("Link Not Available")  #Exception message if urls are not available
            return image_url
        else:
            print("Image not available")

# %%
url =  'https://www.flipkart.com/'
driver = webdriver.Chrome(r"C:/Users/user/Downloads/chromedriver_win32 (1)/chromedriver.exe")
driver.get(url)
driver.maximize_window()
item = input("Enter a smartphone name to search:")
search = driver.find_element_by_xpath('/html/body/div/div/div[1]/div[1]/div[2]/div[2]/form/div/div/input')
search.send_keys(item)
searchbtn = driver.find_element_by_class_name('L0Z3Pu')
b=driver.find_element_by_xpath("//button[@class='_2KpZ6l _2doB4z']")
b.click()   #b=closing login popup 
searchbtn.click()
# Out:
# <ipython-input-14-80549a416a3a>:2: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(r"C:/Users/user/Downloads/chromedriver_win32 (1)/chromedriver.exe")
# Enter a smartphone name to search:samsung galaxy s20+
# <ipython-input-14-80549a416a3a>:6: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   search = driver.find_element_by_xpath('/html/body/div/div/div[1]/div[1]/div[2]/div[2]/form/div/div/input')
# <ipython-input-14-80549a416a3a>:8: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   searchbtn = driver.find_element_by_class_name('L0Z3Pu')
# <ipython-input-14-80549a416a3a>:9: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   b=driver.find_element_by_xpath("//button[@class='_2KpZ6l _2doB4z']")

# %%
produrl = []
produrl_tag = driver.find_elements_by_xpath("//a[@class='_1fQZEK']")
for u in produrl_tag:
     produrl.append(u.get_attribute("href"))

sep = ' | '

produrl
# Out:
# <ipython-input-15-13462a99cef0>:2: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   produrl_tag = driver.find_elements_by_xpath("//a[@class='_1fQZEK']")
# ['https://www.flipkart.com/samsung-galaxy-s20-cloud-blue-128-gb/p/itmce5175ce13e7e?pid=MOBFZXZ2RNFPRFGV&lid=LSTMOBFZXZ2RNFPRFGVGH5EMK&marketplace=FLIPKART&q=samsung+galaxy+s20%2B&store=tyy%2F4io&srno=s_1_1&otracker=search&otracker1=search&fm=SEARCH&iid=0d2057af-fdfd-45dd-974d-02dc60284e34.MOBFZXZ2RNFPRFGV.SEARCH&ppt=hp&ppn=homepage&ssid=161w99jygg0000001641126830366&qH=926cf5144bb33937',
#  'https://www.flipkart.com/samsung-galaxy-s20-cosmic-gray-128-gb/p/itme0dd8ba18500f?pid=MOBFZXZ2VCCBNYHF&lid=LSTMOBFZXZ2VCCBNYHFP9EPIV&marketplace=FLIPKART&q=samsung+galaxy+s20%2B&store=tyy%2F4io&srno=s_1_2&otracker=search&otracker1=search&fm=SEARCH&iid=0d2057af-fdfd-45dd-974d-02dc60284e34.MOBFZXZ2VCCBNYHF.SEARCH&ppt=hp&ppn=homepage&ssid=161w99jygg0000001641126830366&qH=926cf5144bb33937',
#  'https://www.flipkart.com/samsung-galaxy-s20-cloud-pink-128-gb/p/itm8e467fc585444?pid=MOBFZXZ2N3QFFFNZ&lid=LSTMOBFZXZ2N3QFFFNZFEC7TN&marketplace=FLIPKART&q=samsung+galaxy+s20%2B&store=tyy%2F4io&srno=s_1_3&otracker=search&otracker1=search&fm=SEARCH&iid=0d2057af-fdfd-45dd-974d-02dc60284e34.MOBFZXZ2N3QFFFNZ.SEARCH&ppt=hp&ppn=homepage&ssid=161w99jygg0000001641126830366&qH=926cf5144bb33937',
#  'https://www.flipkart.com/samsung-galaxy-a20s-black-32-gb/p/itm3e7775c40a2f8?pid=MOBFKKGRTHKTGUSS&lid=LSTMOBFKKGRTHKTGUSSB20B2W&marketplace=FLIPKART&q=samsung+galaxy+s20%2B&store=tyy%2F4io&srno=s_1_21&otracker=search&otracker1=search&fm=SEARCH&iid=0d2057af-fdfd-45dd-974d-02dc60284e34.MOBFKKGRTHKTGUSS.SEARCH&ppt=hp&ppn=homepage&ssid=161w99jygg0000001641126830366&qH=926cf5144bb33937',
#  'https://www.flipkart.com/samsung-galaxy-s10-plus-prism-blue-128-gb/p/itmfdyp6smfvyhsh?pid=MOBFDNHAQWWD9TDZ&lid=LSTMOBFDNHAQWWD9TDZKKTSPG&marketplace=FLIPKART&q=samsung+galaxy+s20%2B&store=tyy%2F4io&srno=s_1_22&otracker=search&otracker1=search&fm=SEARCH&iid=0d2057af-fdfd-45dd-974d-02dc60284e34.MOBFDNHAQWWD9TDZ.SEARCH&ppt=hp&ppn=homepage&ssid=161w99jygg0000001641126830366&qH=926cf5144bb33937',
#  'https://www.flipkart.com/samsung-galaxy-s10-plus-prism-black-128-gb/p/itmfdyp6xmg64ks5?pid=MOBFDNHAZFKR9Q7Y&lid=LSTMOBFDNHAZFKR9Q7Y5WE0KD&marketplace=FLIPKART&q=samsung+galaxy+s20%2B&store=tyy%2F4io&srno=s_1_23&otracker=search&otracker1=search&fm=SEARCH&iid=0d2057af-fdfd-45dd-974d-02dc60284e34.MOBFDNHAZFKR9Q7Y.SEARCH&ppt=hp&ppn=homepage&ssid=161w99jygg0000001641126830366&qH=926cf5144bb33937',
#  'https://www.flipkart.com/samsung-galaxy-s10-prism-white-128-gb/p/itmfdyp64j3hsfzy?pid=MOBFDNHABB3V23FY&lid=LSTMOBFDNHABB3V23FYF7A1BE&marketplace=FLIPKART&q=samsung+galaxy+s20%2B&store=tyy%2F4io&srno=s_1_24&otracker=search&otracker1=search&fm=SEARCH&iid=0d2057af-fdfd-45dd-974d-02dc60284e34.MOBFDNHABB3V23FY.SEARCH&ppt=hp&ppn=homepage&ssid=161w99jygg0000001641126830366&qH=926cf5144bb33937']

# %%
print(len(produrl))

Brand = []
prod = []
Colour = []
RAM = []
price = []
Storage = []
PrimCamera = []
SecCamera = []
DispSize = []
BatteryCap = []
# Out:
# 24

# %%
for i in produrl:
    driver.get(i)
    time.sleep(3)
    morebtn = driver.find_element_by_xpath("//button[@class='_2KpZ6l _1FH0tX']")
    morebtn.click()
    time.sleep(5)
    try:
        brandtag = driver.find_element_by_xpath("/html/body/div[1]/div/div[3]/div[1]/div[2]/div[1]/div[1]/div/div[4]/a")
        Brand.append(brandtag.text)
    except:
        Brand.append('-')
    try:
        prodtag = driver.find_element_by_xpath("//span[@class='B_NuCI']")
        prod.append(prodtag.text)
    except:
        prod.append('-')
    try:
        Colourtag = driver.find_element_by_xpath("//div[@class='_3k-BhJ'][1]/table/tbody/tr[4]/td[2]/ul/li")
        Colour.append(Colourtag.text)
    except NoSuchElementException:
        Colour.append('-')
    try:
        RAMtag = driver.find_element_by_xpath("//div[@class='_3k-BhJ'][4]/table/tbody/tr[2]/td[2]/ul/li")
        RAM.append(RAMtag.text)
    except:
        RAM.append('-')
    try:
        pricetag = driver.find_element_by_xpath("//div[@class='_30jeq3 _16Jk6d']")
        price.append(pricetag.text)
    except:
        price.append('-')
    
    try:
        Storagetag = driver.find_element_by_xpath("//div[@class='_3k-BhJ'][4]/table/tbody/tr[1]/td[2]/ul/li")
        Storage.append(Storagetag.text)
    except:
        Storage.append('-')
    
    try:
        PrimCameratag = driver.find_element_by_xpath("//div[@class='_2418kt']/ul/li[3]")
        PrimCamera.append(PrimCameratag.text.split(sep, 1)[0])
    except:
        PrimCamera.append('-')
    
    try:
        SecCameratag = driver.find_element_by_xpath("//div[@class='_2418kt']/ul/li[3]")
        SecCamera.append(SecCameratag.text.split(sep, 1)[1])
    except:
        SecCamera.append('-')
    
    try:
        DispSizetag = driver.find_element_by_xpath("//div[@class='_3k-BhJ'][2]/table/tbody/tr[1]/td[2]/ul/li")
        DispSize.append(DispSizetag.text)
    except:
        DispSize.append('-')
    try:
        BatteryCap_tag = driver.find_element_by_xpath("//div[@class='_2418kt']/ul/li[4]")
        BatteryCap.append(BatteryCap_tag.text)
    except:
        BatteryCap.append('-')
# Out:
# <ipython-input-17-05fbc83d932f>:4: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   morebtn = driver.find_element_by_xpath("//button[@class='_2KpZ6l _1FH0tX']")
# <ipython-input-17-05fbc83d932f>:8: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   brandtag = driver.find_element_by_xpath("/html/body/div[1]/div/div[3]/div[1]/div[2]/div[1]/div[1]/div/div[4]/a")
# <ipython-input-17-05fbc83d932f>:13: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   prodtag = driver.find_element_by_xpath("//span[@class='B_NuCI']")
# <ipython-input-17-05fbc83d932f>:18: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   Colourtag = driver.find_element_by_xpath("//div[@class='_3k-BhJ'][1]/table/tbody/tr[4]/td[2]/ul/li")
# <ipython-input-17-05fbc83d932f>:23: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   RAMtag = driver.find_element_by_xpath("//div[@class='_3k-BhJ'][4]/table/tbody/tr[2]/td[2]/ul/li")
# <ipython-input-17-05fbc83d932f>:28: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   pricetag = driver.find_element_by_xpath("//div[@class='_30jeq3 _16Jk6d']")
# <ipython-input-17-05fbc83d932f>:34: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   Storagetag = driver.find_element_by_xpath("//div[@class='_3k-BhJ'][4]/table/tbody/tr[1]/td[2]/ul/li")
# <ipython-input-17-05fbc83d932f>:40: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   PrimCameratag = driver.find_element_by_xpath("//div[@class='_2418kt']/ul/li[3]")
# <ipython-input-17-05fbc83d932f>:46: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   SecCameratag = driver.find_element_by_xpath("//div[@class='_2418kt']/ul/li[3]")
# <ipython-input-17-05fbc83d932f>:52: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   DispSizetag = driver.find_element_by_xpath("//div[@class='_3k-BhJ'][2]/table/tbody/tr[1]/td[2]/ul/li")
# <ipython-input-17-05fbc83d932f>:57: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   BatteryCap_tag = driver.find_element_by_xpath("//div[@class='_2418kt']/ul/li[4]")

# %%
Smartphone = {'Brand Name':Brand,'Smartphone Name':prod,'Price(₹)':price,'Colour':Colour,'RAM':RAM ,'Storage(ROM)':Storage,'Primary Camera':PrimCamera,'Secondary Camera':SecCamera,'Display Size':DispSize,'Battery Capacity':BatteryCap,'Product URL':produrl}

Smartphonedf  = pd.DataFrame(Smartphone)

# 9     ₹37,299                   -  0 0 Octa Core 2.1GHz  Android Lollipop 5
# 10    ₹18,199   Prism Crush Black                  4 GB              128 GB
# 11    ₹49,999         Prism White                  8 GB              128 GB
# 12    ₹14,900               Green                  4 GB               64 GB
# 13    ₹14,990               White                  4 GB               64 GB
# 14    ₹54,999        Cosmic Black                  8 GB              128 GB
# 15    ₹18,900  Prism Crush Violet                  4 GB               64 GB
# 16    ₹15,990                Blue                  6 GB              128 GB
# 17    ₹18,900   Prism Crush White                  4 GB               64 GB
# 18    ₹44,900                   -  0 0 Octa Core 2.1GHz  Android Lollipop 5
# 19    ₹14,069               Black                  4 GB               64 GB
# 20    ₹12,900               Black                  3 GB               32 GB
# 21    ₹59,900          Prism Blue                  8 GB              128 GB
# 22    ₹79,000         Prism Black                  8 GB              128 GB
# 23    ₹58,800         Prism White                  8 GB              128 GB
#
#                                Primary Camera              Secondary Camera  \
# 0                          64MP + 12MP + 12MP             10MP Front Camera
# 1                          64MP + 12MP + 12MP             10MP Front Camera
# 2                          64MP + 12MP + 12MP             10MP Front Camera
# 3               12MP + 12MP + 8MP Rear Camera             32MP Front Camera
# 4                            13MP + 8MP + 5MP              8MP Front Camera
# 5                                 16MP + 12MP  10MP + 8MP Dual Front Camera
# 6                                 16MP + 12MP             10MP Front Camera
# 7   108 MP + 48 MP + 12 MP + VGA Depth Camera             40MP Front Camera
# 8                                 16MP + 12MP  10MP + 8MP Dual Front Camera
# 9                            16MP Rear Camera              5MP Front Camera
# 10                           25MP + 5MP + 8MP             16MP Front Camera
# 11                                16MP + 12MP  10MP + 8MP Dual Front Camera
# 12                           13MP + 8MP + 5MP              8MP Front Camera
# 13                           48MP Rear Camera             16MP Front Camera
# 14    64 MP + 12 MP +12 MP + VGA Depth Camera             10MP Front Camera
# 15                           25MP + 5MP + 8MP             16MP Front Camera
# 16                           48MP + 8MP + 5MP             16MP Front Camera
# 17                           25MP + 5MP + 8MP             16MP Front Camera
# 18                           16MP Rear Camera              5MP Front Camera
# 19                           48MP Rear Camera             16MP Front Camera
# 20                           13MP + 8MP + 5MP              8MP Front Camera
# 21                                16MP + 12MP  10MP + 8MP Dual Front Camera
# 22                                16MP + 12MP  10MP + 8MP Dual Front Camera
# 23                                16MP + 12MP             10MP Front Camera
#
#                                          Display Size  \
# 0                                 15.75 cm (6.2 inch)
# 1                                 15.75 cm (6.2 inch)
# 2                                 15.75 cm (6.2 inch)
# 3                                 16.51 cm (6.5 inch)
# 4                                 16.51 cm (6.5 inch)
# 5                                 16.26 cm (6.4 inch)
# 6                                 15.49 cm (6.1 inch)
# 7                                 17.53 cm (6.9 inch)
# 8                                 16.26 cm (6.4 inch)
# 9   Stereo headset, Travel Adaptor, Data Cable, Ha...
# 10                                16.26 cm (6.4 inch)
# 11                                16.26 cm (6.4 inch)
# 12                                16.51 cm (6.5 inch)
# 13                                16.26 cm (6.4 inch)
# 14                                17.02 cm (6.7 inch)
# 15                                16.26 cm (6.4 inch)
# 16                                16.26 cm (6.4 inch)
# 17                                16.26 cm (6.4 inch)
# 18  Stereo headset, Travel Adaptor, Data Cable, Ha...
write a program to scrap geospatial coordinates (latitude, longitude) of a city searched on google
# maps.

# %%
# Activating the chrome browser
driver=webdriver.Chrome(r"C:/Users/user/Downloads/chromedriver_win32 (1)/chromedriver.exe") 
time.sleep(2)

# opening google maps
url = "https://www.google.co.in/maps"
driver.get(url)
time.sleep(2)


search = driver.find_element_by_id("searchboxinput")                       # locating search bar
search.clear()                                                             # clearing search bar
time.sleep(2)
search.send_keys("New Delhi")                                                     # entering values in search bar
button = driver.find_element_by_id("searchbox-searchbutton")               # locating search button
button.click()                                                             # clicking search button
time.sleep(3)

try:
    url_string = driver.current_url
    print("URL Extracted: ", url_string)
    lat_lng = re.findall(r'@(.*)data',url_string)
    if len(lat_lng):
        lat_lng_list = lat_lng[0].split(",")
        if len(lat_lng_list)>=2:
            lat = lat_lng_list[0]
            lng = lat_lng_list[1]
        print("Latitude = {}, Longitude = {}".format(lat, lng))

except Exception as e:
        print("Error: ", str(e))
# Out:
# <ipython-input-20-af5260a49a66>:2: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver=webdriver.Chrome(r"C:/Users/user/Downloads/chromedriver_win32 (1)/chromedriver.exe")
# <ipython-input-20-af5260a49a66>:11: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   search = driver.find_element_by_id("searchboxinput")                       # locating search bar
# <ipython-input-20-af5260a49a66>:15: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   button = driver.find_element_by_id("searchbox-searchbutton")               # locating search button
# URL Extracted:  https://www.google.co.in/maps/place/New+Delhi,+Delhi/@17.5015649,78.3500765,15z/data=!4m5!3m4!1s0x390cfd5b347eb62d:0x52c2b7494e204dce!8m2!3d28.6139391!4d77.2090212
# Error:  name 're' is not defined

# %%
#6. Write a program to scrap details of all the funding deals for second quarter (i.e Jan 21 – March 21)
#from trak.in.

# %%
url =  'https://www.trak.in'
driver = webdriver.Chrome(r"C:/Users/user/Downloads/chromedriver_win32 (1)/chromedriver.exe") 
driver.get(url)
driver.maximize_window()
# Out:
# <ipython-input-21-0fb84667571c>:2: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(r"C:/Users/user/Downloads/chromedriver_win32 (1)/chromedriver.exe")

# %%
fd = driver.find_element_by_xpath('/html/body/div[1]/header/div[2]/div/div/div/div/nav/ul/li[9]/a')
fd.click()
# Out:
# <ipython-input-22-ff0245e94a76>:1: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   fd = driver.find_element_by_xpath('/html/body/div[1]/header/div[2]/div/div/div/div/nav/ul/li[9]/a')

# %%
date = []
name = []
subvrt = []
indstry = []
city = []
invname = []
invtyp = []
amt = []

table_number = [56,55,54] # when inspecting the page the table number for the March 2021 is 56 ie: id='tablepress-56' and so on

for i in table_number:  
    
    try:
        date_tag = driver.find_elements_by_xpath(f"//*[@id='tablepress-{i}']/tbody/tr/td[2]") 
        for i in date_tag:
            splitdate = i.text.split("/")
            print(splitdate)
            if (str(splitdate[1]) == '03'   or str(splitdate[1]) == '02' or str(splitdate[1]) == '01') and (str(splitdate[2])=='2021'): #checking if the data falls in march/feb/jan of 2021, then store the date
                date.append(i.text)
    except NoSuchElementException:
        date.append('-')

for i in table_number: 
    try:
        name_tag = driver.find_elements_by_xpath(f"//*[@id='tablepress-{i}']/tbody/tr/td[3]/a")
        for j in name_tag:
            name.append(j.text)
    except NoSuchElementException:
        name.append('-') 
        
for i in table_number:  
    try:
        indstry_tag = driver.find_elements_by_xpath(f"//*[@id='tablepress-{i}']/tbody/tr/td[4]")
        for p in indstry_tag:
            indstry.append(p.text)
    except NoSuchElementException:
        indstry.append('-')  
        
for i in table_number:  
    try:
        subvrt_tag = driver.find_elements_by_xpath(f"//*[@id='tablepress-{i}']/tbody/tr/td[5]")
        for k in subvrt_tag:
            subvrt.append(k.text)
    except NoSuchElementException:
        subvrt.append('-')
        
for i in table_number:  
    try:
        city_tag = driver.find_elements_by_xpath(f"//*[@id='tablepress-{i}']/tbody/tr/td[6]")
        for l in city_tag:
            city.append(l.text)
    except NoSuchElementException:
        city.append('-')
        
for i in table_number:
    try:
        invname_tag = driver.find_elements_by_xpath(f"//*[@id='tablepress-{i}']/tbody/tr/td[7]")
        for m in invname_tag:
            invname.append(m.text)
    except NoSuchElementException:
        invname.append('-')
        
for i in table_number:
    try:
        invtyp_tag  = driver.find_elements_by_xpath(f"//*[@id='tablepress-{i}']/tbody/tr/td[8]")
        for n in invtyp_tag:
            invtyp.append(n.text)
    except NoSuchElementException:
        invtyp.append('-')
        
for i in table_number:
    try:
        amt_tag = driver.find_elements_by_xpath(f"//*[@id='tablepress-{i}']/tbody/tr/td[9]")
        for o in amt_tag:
            amt.append(o.text)
    except NoSuchElementException:
        amt.append('-')
name
# Out:
# <ipython-input-23-c74417990c5b>:15: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   date_tag = driver.find_elements_by_xpath(f"//*[@id='tablepress-{i}']/tbody/tr/td[2]")
# <ipython-input-23-c74417990c5b>:26: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   name_tag = driver.find_elements_by_xpath(f"//*[@id='tablepress-{i}']/tbody/tr/td[3]/a")
# <ipython-input-23-c74417990c5b>:34: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   indstry_tag = driver.find_elements_by_xpath(f"//*[@id='tablepress-{i}']/tbody/tr/td[4]")
# <ipython-input-23-c74417990c5b>:42: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   subvrt_tag = driver.find_elements_by_xpath(f"//*[@id='tablepress-{i}']/tbody/tr/td[5]")
# <ipython-input-23-c74417990c5b>:50: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   city_tag = driver.find_elements_by_xpath(f"//*[@id='tablepress-{i}']/tbody/tr/td[6]")
# <ipython-input-23-c74417990c5b>:58: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   invname_tag = driver.find_elements_by_xpath(f"//*[@id='tablepress-{i}']/tbody/tr/td[7]")
# <ipython-input-23-c74417990c5b>:66: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   invtyp_tag  = driver.find_elements_by_xpath(f"//*[@id='tablepress-{i}']/tbody/tr/td[8]")
# <ipython-input-23-c74417990c5b>:74: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   amt_tag = driver.find_elements_by_xpath(f"//*[@id='tablepress-{i}']/tbody/tr/td[9]")
# []

# %%
date
# Out:
# []

# %%
name
# Out:
# []

# %%
for i in range(0,len(invtyp)): #replacing misssing values with '-'
    if invtyp[i]=="":
        invtyp[i] = "-"

# %%
Startup = {'Date':date,'Startup Name':name,'Industry/Vertical':indstry,'Sub-Vertical':subvrt,'City/Location':city ,"Investor's Name":invname,'Investment Type':invtyp,'Amount(in USD)':amt}

Startupdf  = pd.DataFrame(Startup)

# %%
Startupdf
# Out:
# Empty DataFrame
# Columns: [Date, Startup Name, Industry/Vertical, Sub-Vertical, City/Location, Investor's Name, Investment Type, Amount(in USD)]
# Index: []

# %%
#7. Write a program to scrap all the available details of best gaming laptops from digit.in.

# %%
url =  'https://www.digit.in/'
driver=webdriver.Chrome(r"C:/Users/user/Downloads/chromedriver_win32 (1)/chromedriver.exe") 
driver.get(url)
driver.maximize_window()
# Out:
# <ipython-input-29-f05699abcebb>:2: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver=webdriver.Chrome(r"C:/Users/user/Downloads/chromedriver_win32 (1)/chromedriver.exe")

# %%
top10btn = driver.find_element_by_xpath('/html/body/div[1]/div/div[4]/ul/li[4]/a')
top10btn.click()
# Out:
# <ipython-input-30-979a8449f0b9>:1: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   top10btn = driver.find_element_by_xpath('/html/body/div[1]/div/div[4]/ul/li[4]/a')

# %%
gaminglaptopbtn = driver.find_element_by_xpath('/html/body/div[3]/div/div/div[3]/div[2]/ul/li[26]/a')
gaminglaptopbtn.click()
# Out:
# <ipython-input-31-11cf420b0881>:1: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   gaminglaptopbtn = driver.find_element_by_xpath('/html/body/div[3]/div/div/div[3]/div[2]/ul/li[26]/a')

# %%
name = []
os = []
disp = []
mem = []
price = []
Processor = []
GraphProc= []
dim = []
wt = []
desc = []

# %%
name_tag  = driver.find_elements_by_xpath("//*[@id='summtable']/tbody/tr/td[1]")
for n in name_tag:
    name.append(n.text)
price_tag  = driver.find_elements_by_xpath("//*[@id='summtable']/tbody/tr/td[3]")
for p in price_tag:
    price.append(p.text)
os_tag = driver.find_elements_by_xpath("//div[@class='Spcs-details']/table/tbody/tr[3]/td[3]")
for o in os_tag:
    os.append(o.text)
disp_tag = driver.find_elements_by_xpath("//div[@class='Spcs-details']/table/tbody/tr[4]/td[3]")
for d in disp_tag:
    disp.append(d.text)
Processor_tag = driver.find_elements_by_xpath("//div[@class='Spcs-details']/table/tbody/tr[5]/td[3]")
for k in Processor_tag:
    Processor.append(k.text)
GraphProc_tag = driver.find_elements_by_xpath("//div[@class='Spcs-details']/table/tbody/tr[8]/td[3]")
for g in GraphProc_tag:
    GraphProc.append(g.text)
mem_tag = driver.find_elements_by_xpath("//div[@class='Spcs-details']/table/tbody/tr[6]/td[3]")
for m in mem_tag:
    mem.append(g.text)
dim_tag = driver.find_elements_by_xpath("//div[@class='Spcs-details']/table/tbody/tr[9]/td[3]")
for di in dim_tag:
    dim.append(di.text)
wt_tag = driver.find_elements_by_xpath("//div[@class='Spcs-details']/table/tbody/tr[7]/td[3]")
for w in wt_tag:
    wt.append(w.text)
desc_tag = driver.find_elements_by_xpath("//div[@class='Section-center']//p")
for des in desc_tag:
    desc.append(des.text)
# Out:
# <ipython-input-33-96d42c3f01ec>:1: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   name_tag  = driver.find_elements_by_xpath("//*[@id='summtable']/tbody/tr/td[1]")
# <ipython-input-33-96d42c3f01ec>:4: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   price_tag  = driver.find_elements_by_xpath("//*[@id='summtable']/tbody/tr/td[3]")
# <ipython-input-33-96d42c3f01ec>:7: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   os_tag = driver.find_elements_by_xpath("//div[@class='Spcs-details']/table/tbody/tr[3]/td[3]")
# <ipython-input-33-96d42c3f01ec>:10: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   disp_tag = driver.find_elements_by_xpath("//div[@class='Spcs-details']/table/tbody/tr[4]/td[3]")
# <ipython-input-33-96d42c3f01ec>:13: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   Processor_tag = driver.find_elements_by_xpath("//div[@class='Spcs-details']/table/tbody/tr[5]/td[3]")
# <ipython-input-33-96d42c3f01ec>:16: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   GraphProc_tag = driver.find_elements_by_xpath("//div[@class='Spcs-details']/table/tbody/tr[8]/td[3]")
# <ipython-input-33-96d42c3f01ec>:19: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   mem_tag = driver.find_elements_by_xpath("//div[@class='Spcs-details']/table/tbody/tr[6]/td[3]")
# <ipython-input-33-96d42c3f01ec>:22: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   dim_tag = driver.find_elements_by_xpath("//div[@class='Spcs-details']/table/tbody/tr[9]/td[3]")
# <ipython-input-33-96d42c3f01ec>:25: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   wt_tag = driver.find_elements_by_xpath("//div[@class='Spcs-details']/table/tbody/tr[7]/td[3]")
# <ipython-input-33-96d42c3f01ec>:28: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   desc_tag = driver.find_elements_by_xpath("//div[@class='Section-center']//p")

# %%
while('AVAILABLE' in desc):
    desc.remove("AVAILABLE")

# %%
Laptops = {'Laptop Name':name,'Operating System':os,'Display': disp,'Processor':Processor,'Graphics Processor':GraphProc ,'Memory':mem,'Dimensions':dim,'Weight(kg)':wt,'Price(₹)':price,'Details':desc}

Laptops  = pd.DataFrame(Laptops)
Laptops
# Out:
#                                      Laptop Name Operating System  \
# 0                    Acer NITRO 5 Ryzen 9 (2021)       Windows 10
# 1  MSI Stealth 15M 11th Gen Core i7-11375H (2021       Windows 10
# 2   ASUS ROG Strix Scar 15 Ryzen 9-5900HX (2021)       Windows 10
# 3                          Alienware Area 51M R2  Windows 10 Home
# 4                               Alienware m15 R3  Windows 10 Home
# 5                         ASUS ROG Strix Scar 15  Windows 10 Home
# 6                          Asus ROG Zephyrus G14  Windows 10 Home
# 7                               Lenovo Legion 5i   Windows 10 Pro
# 8                       ASUS ROG ZEPHYRUS DUO 15       Windows 10
# 9                           Acer Aspire 7 gaming  Windows 10 Home
#
#                Display                                   Processor  \
# 0  15.6" (1920 x 1080)             AMD Ryzen 9 Octa Core | 2.4 GHz
# 1  15.6" (1920 x 1080)        Intel Core i7 11th Gen - 11375H | NA
# 2  15.6" (2560 x 1440)    AMD Ryzen 9 Octa Core - 5900HX | 3.3 GHz
# 3  17.3" (1920 x 1080)   10th Gen Intel® Core™ i7-10700 | 2.90 GHz
# 4  15.6" (3840 x 2160)       10th Gen Intel® Core™ i9-10980HK | NA
# 5  15.6" (1920 x 1080)               AMD Ryzen™ 9 5900HX | 3.3 GHz
# 6    14" (1920 x 1080)               AMD 3rd Gen Ryzen 9 | 3.3 GHz
# 7  15.6" (1920 x 1080)  10th Gen Intel® Core™ i5-10300H | 2.50 GHz
# 8  15.6" (3840 x 1100)          Intel Core i7 10th Gen 10875H | NA
# 9  15.6" (1920 x 1080)           AMD Ryzen™ 5-5500U hexa-core | NA
#
#         Graphics Processor              Memory                     Dimensions  \
# 0       363.4 x 255 x 23.9  2.29 x 36.3 x 25.4        NVIDIA GeForce RTX 3070
# 1      358.3 x 248 x 16.15  2.29 x 36.3 x 25.4        NVIDIA GeForce RTX 3060
# 2         354 x 259 x 22.6  2.29 x 36.3 x 25.4        NVIDIA GeForce RTX 3080
# 3   27.65 x 402.6 x 319.14  2.29 x 36.3 x 25.4        Intel® UHD Graphics 630
# 4                       NA  2.29 x 36.3 x 25.4                             NA
# 5       35.4 x 25.9 x 2.26  2.29 x 36.3 x 25.4      NVIDIA® GeForce RTX™ 3070
# 6        32.5 x 22.1 x 1.8  2.29 x 36.3 x 25.4        NVIDIA GeForce RTX 2060
# 7  363.06 x 259.61 x 23.57  2.29 x 36.3 x 25.4  NVIDIA® GeForce® GTX 1650 4GB
# 8  268.30 x 360.00 x 20.90  2.29 x 36.3 x 25.4  NVIDIA GeForce RTX 2070 Max-Q
# 9       2.29 x 36.3 x 25.4  2.29 x 36.3 x 25.4      NVIDIA® GeForce® GTX 1650
#
#   Weight(kg)   Price(₹)                                            Details
# 0        2.4  ₹ 129,990  Possibly the best value-for-money gaming lapto...
# 1        1.7  ₹ 134,990  If you’re looking for a powerful gaming laptop...
# 2       2.30  ₹ 268,990  If you want possibly the best performance poss...
# 3        4.1  ₹ 342,989  If you want the absolute best when it comes to...
# 4         NA  ₹ 319,990  If the Area 51M is a bit too much for you then...
# 5       2.30  ₹ 215,990  When the ASUS ROG Strix Scar 15 ended up on ou...
# 6       1.65  ₹ 164,990  The Asus Zephyrus G14 is a first-of-its-kind g...
# 7        2.3   ₹ 76,988  Lenovo's Legion 5i is also a suitable laptop f...
# 8        2.4  ₹ 185,000  The machine is powered by an Intel Core i7-108...
# 9       2.15   ₹ 58,480  The Acer Aspire 7 gaming laptop is a very capa...

# %% [markdown]
# 8. Write a python program to scrape the details for all billionaires from www.forbes.com. Details to be
# scrapped: “Rank”, “Name”, “Net worth”, “Age”, “Citizenship”, “Source”, “Industry”.

# %%
url =  'https://www.forbes.com'
driver=webdriver.Chrome(r"C:/Users/user/Downloads/chromedriver_win32 (1)/chromedriver.exe") 
driver.get(url)
driver.maximize_window()
# Out:
# <ipython-input-36-712d8e027d41>:2: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver=webdriver.Chrome(r"C:/Users/user/Downloads/chromedriver_win32 (1)/chromedriver.exe")

# %%
xplbtn = driver.find_element_by_xpath('/html/body/div[1]/header/nav/div[1]/button[1]')
xplbtn.click()
# Out:
# <ipython-input-37-10685bf2d3c8>:1: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   xplbtn = driver.find_element_by_xpath('/html/body/div[1]/header/nav/div[1]/button[1]')

# %%
bilbtn = driver.find_element_by_xpath('/html/body/div[1]/header/nav/div[3]/ul/li[1]')
bilbtn.click() #clicking on Billionaires button
allbtn =  driver.find_element_by_xpath('/html/body/div[1]/header/nav/div[3]/ul/li[1]/div[2]/ul/li[2]/a')
allbtn.click() #clicking on World's Billionaires button
# Out:
# <ipython-input-38-9892d6738443>:1: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   bilbtn = driver.find_element_by_xpath('/html/body/div[1]/header/nav/div[3]/ul/li[1]')
# <ipython-input-38-9892d6738443>:3: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   allbtn =  driver.find_element_by_xpath('/html/body/div[1]/header/nav/div[3]/ul/li[1]/div[2]/ul/li[2]/a')

# %%
rank = []
name = []
netwrth = []
age = []
cit = []
src = []
ind = []

# %%
rank_tag = driver.find_elements_by_xpath("//div[@class='rank']")
name_tag = driver.find_elements_by_xpath("//div[@class='personName']//div")
netwrth_tag = driver.find_elements_by_xpath("//div[@class='netWorth']//div")
age_tag = driver.find_elements_by_xpath("//div[@class='age']//div")
cit_tag = driver.find_elements_by_xpath("//div[@class='countryOfCitizenship']")
src_tag = driver.find_elements_by_xpath("//div[@class='source-column']//div")
ind_tag = driver.find_elements_by_xpath("//div[@class='category']//div")
# Out:
# <ipython-input-40-a20a118c545d>:1: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   rank_tag = driver.find_elements_by_xpath("//div[@class='rank']")
# <ipython-input-40-a20a118c545d>:2: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   name_tag = driver.find_elements_by_xpath("//div[@class='personName']//div")
# <ipython-input-40-a20a118c545d>:3: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   netwrth_tag = driver.find_elements_by_xpath("//div[@class='netWorth']//div")
# <ipython-input-40-a20a118c545d>:4: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   age_tag = driver.find_elements_by_xpath("//div[@class='age']//div")
# <ipython-input-40-a20a118c545d>:5: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   cit_tag = driver.find_elements_by_xpath("//div[@class='countryOfCitizenship']")
# <ipython-input-40-a20a118c545d>:6: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   src_tag = driver.find_elements_by_xpath("//div[@class='source-column']//div")
# <ipython-input-40-a20a118c545d>:7: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   ind_tag = driver.find_elements_by_xpath("//div[@class='category']//div")

# %%
for r in rank_tag:
    rank.append(r.text)
for n in name_tag:
    name.append(n.text)
for nt in netwrth_tag:
    netwrth.append(nt.text)
for a in age_tag:
    age.append(a.text)
for c in cit_tag:
    cit.append(c.text)
for s in src_tag:
    src.append(s.text)

for i in ind_tag:
    ind.append(i.text)

# %%
import time 


i=0

while(i<=12):
    
    nextbtn = driver.find_element_by_xpath("//div[@class='next-page']")
    nextbtn.click()
    time.sleep(3)
    
    rank_tag = driver.find_elements_by_xpath("//div[@class='rank']")
    name_tag = driver.find_elements_by_xpath("//div[@class='personName']//div")
    netwrth_tag = driver.find_elements_by_xpath("//div[@class='netWorth']//div")
    age_tag = driver.find_elements_by_xpath("//div[@class='age']//div")
    cit_tag = driver.find_elements_by_xpath("//div[@class='countryOfCitizenship']")
    src_tag = driver.find_elements_by_xpath("//div[@class='source-column']//div")
    ind_tag = driver.find_elements_by_xpath("//div[@class='category']//div")
    for r in rank_tag:
            rank.append(r.text)
    for n in name_tag:
            name.append(n.text)
    for nt in netwrth_tag:
            netwrth.append(nt.text)
    for a in age_tag:
            age.append(a.text)
    for c in cit_tag:
            cit.append(c.text)  
    for s in src_tag:
            src.append(s.text)
    for k in ind_tag:
            ind.append(k.text)
    
    i=i+1
# Out:
# <ipython-input-42-663c7afd5eda>:8: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   nextbtn = driver.find_element_by_xpath("//div[@class='next-page']")
# <ipython-input-42-663c7afd5eda>:12: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   rank_tag = driver.find_elements_by_xpath("//div[@class='rank']")
# <ipython-input-42-663c7afd5eda>:13: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   name_tag = driver.find_elements_by_xpath("//div[@class='personName']//div")
# <ipython-input-42-663c7afd5eda>:14: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   netwrth_tag = driver.find_elements_by_xpath("//div[@class='netWorth']//div")
# <ipython-input-42-663c7afd5eda>:15: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   age_tag = driver.find_elements_by_xpath("//div[@class='age']//div")
# <ipython-input-42-663c7afd5eda>:16: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   cit_tag = driver.find_elements_by_xpath("//div[@class='countryOfCitizenship']")
# <ipython-input-42-663c7afd5eda>:17: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   src_tag = driver.find_elements_by_xpath("//div[@class='source-column']//div")
# <ipython-input-42-663c7afd5eda>:18: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   ind_tag = driver.find_elements_by_xpath("//div[@class='category']//div")

# %%
while('' in netwrth):  #removing empty string values from netwrth
    netwrth.remove("")

# %%
for i in range(0,len(src)):
    if src[i] == '★': # replacing unwanted symbol with empty string
        src[i] = ''

# %%
while('' in src):  #removing empty string values from src
    src.remove("")

# %%
Billionaires = {'Rank':rank,'Name':name,'Net Worth':netwrth,'Age': age,'Citizenship/Country':cit,'Source':src,'Industry':ind}

BillionairesDF  = pd.DataFrame(Billionaires)

BillionairesDF
# Out:
#        Rank                      Name Net Worth Age Citizenship/Country  \
# 0        1.                Jeff Bezos    $177 B  57       United States
# 1        2.                 Elon Musk    $151 B  49       United States
# 2        3.  Bernard Arnault & family    $150 B  72              France
# 3        4.                Bill Gates    $124 B  65       United States
# 4        5.           Mark Zuckerberg     $97 B  36       United States
# ...     ...                       ...       ...  ..                 ...
# 2750  2674.         Daniel Yong Zhang      $1 B  49               China
# 2751  2674.             Zhang Yuqiang      $1 B  65               China
# 2752  2674.             Zhao Meiguang      $1 B  58               China
# 2753  2674.            Zhong Naixiong      $1 B  58               China
# 2754  2674.           Zhou Wei family      $1 B  54               China
#
#              Source          Industry
# 0            Amazon        Technology
# 1     Tesla, SpaceX        Automotive
# 2              LVMH  Fashion & Retail
# 3         Microsoft        Technology
# 4          Facebook        Technology
# ...             ...               ...
# 2750     e-commerce        Technology
# 2751     Fiberglass     Manufacturing
# 2752    gold mining   Metals & Mining
# 2753   conglomerate       Diversified
# 2754       Software        Technology
#
# [2755 rows x 7 columns]

# %% [markdown]
# 9. Write a program to extract at least 500 Comments, Comment upvote and time when comment was posted
# from any YouTube Video.

# %%
url = input('Enter Youtube video URL:')
# Out:
# Enter Youtube video URL:https://www.youtube.com/watch?v=8LwIk99qYyo

# %%
driver = webdriver.Chrome(r"C:/Users/user/Downloads/chromedriver_win32 (1)/chromedriver.exe")
driver.get(url)
# Out:
# <ipython-input-48-f28363bc84c4>:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(r"C:/Users/user/Downloads/chromedriver_win32 (1)/chromedriver.exe")

# %%
i=0
while(i<100):
    driver.execute_script("window.scrollBy(0,500)") # scroll down to get more comments
    i+=1
while(i<402):
    driver.execute_script("window.scrollBy(0,5000)") # scroll down to get more comments
    i+=1
# Out:
# ---------------------------------------------------------------------------
# WebDriverException                        Traceback (most recent call last)
# <ipython-input-49-ceaabfe2bfd0> in <module>
#       1 i=0
#       2 while(i<100):
# ----> 3     driver.execute_script("window.scrollBy(0,500)") # scroll down to get more comments
#       4     i+=1
#       5 while(i<402):
#
# E:\AANI\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute_script(self, script, *args)
#     876         command = Command.W3C_EXECUTE_SCRIPT
#     877
# --> 878         return self.execute(command, {
#     879             'script': script,
#     880             'args': converted_args})['value']
#
# E:\AANI\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     422         response = self.command_executor.execute(driver_command, params)
#     423         if response:
# --> 424             self.error_handler.check_response(response)
#     425             response['value'] = self._unwrap_value(
#     426                 response.get('value', None))
#
# E:\AANI\lib\site-packages\selenium\webdriver\remote\errorhandler.py in check_response(self, response)
#     245                 alert_text = value['alert'].get('text')
#     246             raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 247         raise exception_class(message, screen, stacktrace)
#     248
#     249     def _value_or_default(self, obj: Mapping[_KT, _VT], key: _KT, default: _VT) -> _VT:
#
# WebDriverException: Message: chrome not reachable
#   (Session info: chrome=96.0.4664.110)
# Stacktrace:
# Backtrace:
# 	Ordinal0 [0x003C6903+2517251]
# 	Ordinal0 [0x0035F8E1+2095329]
# 	Ordinal0 [0x00262710+1058576]
# 	Ordinal0 [0x002576A4+1013412]
# 	Ordinal0 [0x00257EA8+1015464]
# 	Ordinal0 [0x00259695+1021589]
# 	Ordinal0 [0x00253686+996998]
# 	Ordinal0 [0x00263A60+1063520]
# 	Ordinal0 [0x002B5382+1397634]
# 	Ordinal0 [0x002A639B+1336219]
# 	Ordinal0 [0x002827A7+1189799]
# 	Ordinal0 [0x00283609+1193481]
# 	GetHandleVerifier [0x00555904+1577972]
# 	GetHandleVerifier [0x00600B97+2279047]
# 	GetHandleVerifier [0x00456D09+534521]
# 	GetHandleVerifier [0x00455DB9+530601]
# 	Ordinal0 [0x00364FF9+2117625]
# 	Ordinal0 [0x003698A8+2136232]
# 	Ordinal0 [0x003699E2+2136546]
# 	Ordinal0 [0x00373541+2176321]
# 	BaseThreadInitThunk [0x750686E3+14]
# 	RtlInitializeExceptionChain [0x7759BD99+133]
# 	RtlInitializeExceptionChain [0x7759BD6C+88]

# %%
cmt = []
upvt = []
cmttime = []

# %%
cmt_tag = driver.find_elements_by_xpath("//*[@id='content-text']")
for i in cmt_tag:
    cmt.append(i.text.replace("\n",''))

upvt_tag = driver.find_elements_by_xpath("//*[@id='vote-count-middle']")
for j in upvt_tag:
    try: 
        upvt.append(j.text)
    except:
        upvt.append('-')
cmttime_tag = driver.find_elements_by_xpath("//*[@id='header-author']/yt-formatted-string/a")
for k in cmttime_tag:
    try: 
        cmttime.append(k.text)
    except:
        cmttime.append('-')
# Out:
# <ipython-input-51-857230ffdd12>:1: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   cmt_tag = driver.find_elements_by_xpath("//*[@id='content-text']")
# ---------------------------------------------------------------------------
# WebDriverException                        Traceback (most recent call last)
# <ipython-input-51-857230ffdd12> in <module>
# ----> 1 cmt_tag = driver.find_elements_by_xpath("//*[@id='content-text']")
#       2 for i in cmt_tag:
#       3     cmt.append(i.text.replace("\n",''))
#       4
#       5 upvt_tag = driver.find_elements_by_xpath("//*[@id='vote-count-middle']")
#
# E:\AANI\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_elements_by_xpath(self, xpath)
#     541             stacklevel=2,
#     542         )
# --> 543         return self.find_elements(by=By.XPATH, value=xpath)
#     544
#     545     def find_element_by_link_text(self, link_text) -> WebElement:
#
# E:\AANI\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_elements(self, by, value)
#    1277         # Return empty list if driver returns null
#    1278         # See https://github.com/SeleniumHQ/selenium/issues/4555
# -> 1279         return self.execute(Command.FIND_ELEMENTS, {
#    1280             'using': by,
#    1281             'value': value})['value'] or []
#
# E:\AANI\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     422         response = self.command_executor.execute(driver_command, params)
#     423         if response:
# --> 424             self.error_handler.check_response(response)
#     425             response['value'] = self._unwrap_value(
#     426                 response.get('value', None))
#
# E:\AANI\lib\site-packages\selenium\webdriver\remote\errorhandler.py in check_response(self, response)
#     245                 alert_text = value['alert'].get('text')
#     246             raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 247         raise exception_class(message, screen, stacktrace)
#     248
#     249     def _value_or_default(self, obj: Mapping[_KT, _VT], key: _KT, default: _VT) -> _VT:
#
# WebDriverException: Message: chrome not reachable
#   (Session info: chrome=96.0.4664.110)
# Stacktrace:
# Backtrace:
# 	Ordinal0 [0x003C6903+2517251]
# 	Ordinal0 [0x0035F8E1+2095329]
# 	Ordinal0 [0x00262710+1058576]
# 	Ordinal0 [0x002576A4+1013412]
# 	Ordinal0 [0x00257EA8+1015464]
# 	Ordinal0 [0x00259695+1021589]
# 	Ordinal0 [0x00253686+996998]
# 	Ordinal0 [0x00263A60+1063520]
# 	Ordinal0 [0x002B5382+1397634]
# 	Ordinal0 [0x002A639B+1336219]
# 	Ordinal0 [0x002827A7+1189799]
# 	Ordinal0 [0x00283609+1193481]
# 	GetHandleVerifier [0x00555904+1577972]
# 	GetHandleVerifier [0x00600B97+2279047]
# 	GetHandleVerifier [0x00456D09+534521]
# 	GetHandleVerifier [0x00455DB9+530601]
# 	Ordinal0 [0x00364FF9+2117625]
# 	Ordinal0 [0x003698A8+2136232]
# 	Ordinal0 [0x003699E2+2136546]
# 	Ordinal0 [0x00373541+2176321]
# 	BaseThreadInitThunk [0x750686E3+14]
# 	RtlInitializeExceptionChain [0x7759BD99+133]
# 	RtlInitializeExceptionChain [0x7759BD6C+88]

# %%
for i in range(0,len(upvt)):
    if upvt[i] == '': 
        upvt[i] = '-'

# %%
Youtube = {'Comment':cmt,'Commented':cmttime,'Number of upvotes':upvt}

# %%
YoutubeDF = pd.DataFrame(Youtube)

# %%
YoutubeDF
# Out:
# Empty DataFrame
# Columns: [Comment, Commented, Number of upvotes]
# Index: []

# %% [markdown]
# 10. Write a python program to scrape a data for all available Hostels from https://www.hostelworld.com/ in
# “London” location. You have to scrape hostel name, distance from city centre, ratings, total reviews,
# overall reviews, privates from price, dorms from price, facilities and property description.

# %%
# Activating the chrome browser
driver=webdriver.Chrome(r"C:/Users/user/Downloads/chromedriver_win32 (1)/chromedriver.exe") 
time.sleep(3)

# Opening the homepage of hostelworld.com
url = "https://www.hostelworld.com/"
driver.get(url)
# Out:
# <ipython-input-56-cc1e15ff94bd>:2: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver=webdriver.Chrome(r"C:/Users/user/Downloads/chromedriver_win32 (1)/chromedriver.exe")

# %%
#locating the location search bar
search_loc = driver.find_element_by_id('search-input-field')
# write Lonodn in search bar
search_loc.send_keys("London")
time.sleep(2)

# #select london
london = driver.find_element_by_xpath('/html/body/div[3]/div/div/div[1]/div[1]/div/div[2]/div[4]/div/div[2]/div/div[1]/div/div/ul/li[2]/div')
london.click()
time.sleep(2)


# do click on search button
search_btn = driver.find_element_by_id('search-button')
search_btn.click()
# Out:
# <ipython-input-57-e7522fda4918>:2: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   search_loc = driver.find_element_by_id('search-input-field')
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# <ipython-input-57-e7522fda4918> in <module>
#       1 #locating the location search bar
# ----> 2 search_loc = driver.find_element_by_id('search-input-field')
#       3 # write Lonodn in search bar
#       4 search_loc.send_keys("London")
#       5 time.sleep(2)
#
# E:\AANI\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element_by_id(self, id_)
#     470             stacklevel=2,
#     471         )
# --> 472         return self.find_element(by=By.ID, value=id_)
#     473
#     474     def find_elements_by_id(self, id_) -> WebElement:
#
# E:\AANI\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element(self, by, value)
#    1242             value = '[name="%s"]' % value
#    1243
# -> 1244         return self.execute(Command.FIND_ELEMENT, {
#    1245             'using': by,
#    1246             'value': value})['value']
#
# E:\AANI\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     422         response = self.command_executor.execute(driver_command, params)
#     423         if response:
# --> 424             self.error_handler.check_response(response)
#     425             response['value'] = self._unwrap_value(
#     426                 response.get('value', None))
#
# E:\AANI\lib\site-packages\selenium\webdriver\remote\errorhandler.py in check_response(self, response)
#     245                 alert_text = value['alert'].get('text')
#     246             raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 247         raise exception_class(message, screen, stacktrace)
#     248
#     249     def _value_or_default(self, obj: Mapping[_KT, _VT], key: _KT, default: _VT) -> _VT:
#
# NoSuchElementException: Message: no such element: Unable to locate element: {"method":"css selector","selector":"[id="search-input-field"]"}
#   (Session info: chrome=96.0.4664.110)
# Stacktrace:
# Backtrace:
# 	Ordinal0 [0x003C6903+2517251]
# 	Ordinal0 [0x0035F8E1+2095329]
# 	Ordinal0 [0x00262848+1058888]
# 	Ordinal0 [0x0028D448+1233992]
# 	Ordinal0 [0x0028D63B+1234491]
# 	Ordinal0 [0x002B7812+1406994]
# 	Ordinal0 [0x002A650A+1336586]
# 	Ordinal0 [0x002B5BBF+1399743]
# 	Ordinal0 [0x002A639B+1336219]
# 	Ordinal0 [0x002827A7+1189799]
# 	Ordinal0 [0x00283609+1193481]
# 	GetHandleVerifier [0x00555904+1577972]
# 	GetHandleVerifier [0x00600B97+2279047]
# 	GetHandleVerifier [0x00456D09+534521]
# 	GetHandleVerifier [0x00455DB9+530601]
# 	Ordinal0 [0x00364FF9+2117625]
# 	Ordinal0 [0x003698A8+2136232]
# 	Ordinal0 [0x003699E2+2136546]
# 	Ordinal0 [0x00373541+2176321]
# 	BaseThreadInitThunk [0x750686E3+14]
# 	RtlInitializeExceptionChain [0x7759BD99+133]
# 	RtlInitializeExceptionChain [0x7759BD6C+88]

# %%
# Make empty lists
Hostel_Name = []
Distance = []
overall_review = []
total_reviews = []
facilities = []
price = []
Rating = []
property_description = []

# %%
while(True):
    
    # Hostel name
    names = driver.find_elements_by_xpath('//h2[@class="title title-6"]')
    for name in names:
        Hostel_Name.append(name.text)
    time.sleep(2)
        
    # Distance from city centre
    dis = driver.find_elements_by_xpath('//span[@class="description"]')
    for d in dis:
        Distance.append(d.text)
    time.sleep(2)
        
    # Overall Review    
    review = driver.find_elements_by_xpath('//div[@class="keyword"]//span')
    for r in review:
        overall_review.append(r.text)
    time.sleep(2)
    
    # Total No of reviews     
    t_review = driver.find_elements_by_xpath('//div[@class="reviews"]')
    for tr in t_review:
        total_reviews.append(tr.text)
    time.sleep(2)
    
    # facilities
    service = driver.find_elements_by_xpath('//div[@class="facilities-label facilities"]')
    for s in service:
        facilities.append(s.text)
    time.sleep(2)
    
    # Prices    
    prices = driver.find_elements_by_xpath('//div[@class="price-col"]')
    for p in prices:
        price.append(p.text)
    time.sleep(2)    
        
    try:
        next_button = driver.find_element_by_xpath('//div[@class="pagination-item pagination-next"]')
        next_button.click()
    except:
        break
        
time.sleep(4)        
        
# Separate  Privates_From price  and  Dorms_From price
Privates_From = []
for i in range(0,len(price),2):
    Privates_From.append(price[i])
time.sleep(2)

Dorms_From = []
for i in range(1,len(price),2):
    Dorms_From.append(price[i])
# Out:
# <ipython-input-59-a9a9e1154c97>:4: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   names = driver.find_elements_by_xpath('//h2[@class="title title-6"]')
# <ipython-input-59-a9a9e1154c97>:10: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   dis = driver.find_elements_by_xpath('//span[@class="description"]')
# <ipython-input-59-a9a9e1154c97>:16: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   review = driver.find_elements_by_xpath('//div[@class="keyword"]//span')
# <ipython-input-59-a9a9e1154c97>:22: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   t_review = driver.find_elements_by_xpath('//div[@class="reviews"]')
# <ipython-input-59-a9a9e1154c97>:28: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   service = driver.find_elements_by_xpath('//div[@class="facilities-label facilities"]')
# <ipython-input-59-a9a9e1154c97>:34: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   prices = driver.find_elements_by_xpath('//div[@class="price-col"]')
# <ipython-input-59-a9a9e1154c97>:40: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   next_button = driver.find_element_by_xpath('//div[@class="pagination-item pagination-next"]')

# %%
# scrape Hostels URL
hostel_url = []

while(True):
    urls = driver.find_elements_by_xpath('//h2[@class="title title-6"]//a')
    for url in urls:
        hostel_url.append(url.get_attribute("href"))
    time.sleep(2)    
        
    try:
        next_button = driver.find_element_by_xpath('//div[@class="pagination-item pagination-next"]')
        next_button.click()
    except:
        break


        
Rate = []
for page in hostel_url:
    driver.get(page)
    
    # Rating
    try:
        ratings = driver.find_element_by_xpath('/html/body/div[1]/div/div/div[1]/section/div[6]/div/div[1]/div[1]/div[1]')
        Rate.append(ratings.text)
    except NoSuchElementException:
        Rate.append("No Rating")  
    time.sleep(2)
    
    
    # Property Description
    try:
        pd = driver.find_element_by_xpath('/html/body/div[1]/div/div/div[1]/section/div[6]/div/div[2]/div[2]/div/div[2]')
        property_description.append(pd.text)
    except NoSuchElementException:
        property_description.append("No Description")  

    
time.sleep(2)        
# remove extra data from Rating     
all_text = []
for i in Rate:
    all_text.append(i.split())
time.sleep(2)

for i in all_text:
    Rating.append(i[0])
# Out:
# <ipython-input-60-ef74696f6f6c>:5: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   urls = driver.find_elements_by_xpath('//h2[@class="title title-6"]//a')
# <ipython-input-60-ef74696f6f6c>:11: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   next_button = driver.find_element_by_xpath('//div[@class="pagination-item pagination-next"]')

# %%
#creating dataframe
df = pd.DataFrame({'Hostel Name':Name[5],
                'Distance from city centre':Distance[5],
                'Overall Review':overall_review[2:10],
                'Total Reviews':total_reviews[5],
                'Facilities':facilities[5],
                'Privates From Price':Privates_From[5],
                'Dorms From Price':Dorms_From[5],
                'Rating':Rating[5],
                'Property Description':property_description[5]})
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-64-57c1fcbaa4e1> in <module>
#       1 #creating dataframe
# ----> 2 df = pd.DataFrame({'Hostel Name':Name[5],
#       3                 'Distance from city centre':Distance[5],
#       4                 'Overall Review':overall_review[2:10],
#       5                 'Total Reviews':total_reviews[5],
#
# NameError: name 'Name' is not defined
